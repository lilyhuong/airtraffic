# %%
import pandas as pd

# %%
pd.read_parquet("/Users/lilyhuong/Desktop/Amse mag3/semestre 2/Forecast air traffic/airtraffic/traffic_light (1).parquet")
# Out:
#          movementDate  paxTotal  seats  atm  flightCancelled  \
# 4070514    2016-01-01     120.0  156.0  1.0              0.0
# 9342108    2016-01-01      28.0   86.0  1.0              NaN
# 2237428    2016-01-01     136.0  156.0  1.0              NaN
# 7982167    2016-01-01       1.0    9.0  1.0              NaN
# 3768297    2016-01-01     137.0  186.0  1.0              0.0
# ...               ...       ...    ...  ...              ...
# 9298812    2016-06-29      19.0   50.0  1.0              NaN
# 1155660    2016-06-29       1.0    NaN  1.0              0.0
# 3281598    2016-06-29     180.0  180.0  1.0              0.0
# 8606335    2016-06-29     106.0  150.0  1.0              NaN
# 10282417   2016-06-29      80.0   99.0  1.0              NaN
#
#          flightTypeCodeGlobal flightTypeNameGlobal homeAirportCode  \
# 4070514                     J            Scheduled             LGW
# 9342108                  None            Scheduled             MTY
# ...

# %%
traffic_df.describle( include = 'all').transpose()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 traffic_df.describle( include = 'all').transpose()
#
# NameError: name 'traffic_df' is not defined
